# %% [markdown]
# ## Exercise 5.1
# ### 1. Inspecting your data
#
# You can use the DataFrame methods ```.head()``` and ```.tail()``` to view the first few and last few rows of a DataFrame. In this exercise, the dataset, containing wolrd population data from 1960 to 2014, was obtained from the World Bank.
#
# #### Instructions (2 points)
#
# - import pandas using alias `pd`
# - Examine the first and last few rows of the dataframe.

# %%
import pandas as pd
wb_df = pd.read_csv('https://github.com/huangpen77/BUDT704/raw/main/Chapter06/world_ind_pop_data.csv')

# print the first few rows 
wb_df.head()
# Out:
#                                CountryName CountryCode  Year  \
# 0                               Arab World         ARB  1960
# 1                   Caribbean small states         CSS  1960
# 2           Central Europe and the Baltics         CEB  1960
# 3  East Asia & Pacific (all income levels)         EAS  1960
# 4    East Asia & Pacific (developing only)         EAP  1960
#
#    Total Population  Urban population (% of total)
# 0      9.249590e+07                      31.285384
# 1      4.190810e+06                      31.597490
# 2      9.140158e+07                      44.507921
# 3      1.042475e+09                      22.471132
# 4      8.964930e+08                      16.917679

# %%
# print the last few rows
wb_df.tail()
# Out:
#                  CountryName CountryCode  Year  Total Population  \
# 13369  Virgin Islands (U.S.)         VIR  2014          104170.0
# 13370     West Bank and Gaza         WBG  2014         4294682.0
# 13371            Yemen, Rep.         YEM  2014        26183676.0
# 13372                 Zambia         ZMB  2014        15721343.0
# 13373               Zimbabwe         ZWE  2014        15245855.0
#
#        Urban population (% of total)
# 13369                         95.203
# 13370                         75.026
# 13371                         34.027
# 13372                         40.472
# 13373                         32.501

# %% [markdown]
# ### 2. DataFrame data types
#
# Pandas is aware of the data types in the columns of your DataFrame, as well as the number of observations. In this exercise, you will find out the data types of all the columns.
#
# #### Instructions (2 points)
#
# - Find out the name of the columns and their data types, using DataFrame `info()` method.
# - Determine the shape and find out the numbers of rows and columns in the dataset.

# %%
wb_df.info()
wb_df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13374 entries, 0 to 13373
# Data columns (total 5 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   CountryName                    13374 non-null  object
#  1   CountryCode                    13374 non-null  object
#  2   Year                           13374 non-null  int64
#  3   Total Population               13374 non-null  float64
#  4   Urban population (% of total)  13374 non-null  float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 522.5+ KB
# (13374, 5)

# %% [markdown]
# ### 3. Pandas Series
#
# #### Instructions (1 point)
# - Retrive the `CountryCode` column from `wb-df`, and print out its type

# %%
type(wb_df['CountryCode'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### Instructions (1 point)
# - pandas Series has a `.nunique()` method which returns the number of unique elements in the Series. Use it to find out the number of unique elements in the `CountryCode` column from `wb-df`

# %%
wb_df['CountryCode'].nunique()
# Out:
# 245

# %% [markdown]
# ### Instructions (1 point)
# - pandas Series has a `.value_counts()` method which returns the counts of unique values. Use it to find out the counts of unique values in the `CountryCode` column from `wb-df`

# %%
wb_df['CountryCode'].value_counts()
# Out:
# ARB    55
# PER    55
# MHL    55
# MRT    55
# MUS    55
#        ..
# CRI    55
# KWT    52
# SRB    25
# WBG    25
# SXM    17
# Name: CountryCode, Length: 245, dtype: int64

# %% [markdown]
# ## Exercise 5.2 Sorting and Filtering

# %% [markdown]
# ### 1. Sort DataFrame values
#
# You can use DataFrame ```sort_values()``` method to sort the rows of a DataFrame.
# #### Instructions (2 points)
#
# - Sort the wb_df DataFrame first by `CountryName` in ascending order, then by `Year` by descending order.

# %%
wb_df.sort_values(['CountryName', 'Year'], ascending=[True, False])
# Out:
#        CountryName CountryCode  Year  Total Population  \
# 13162  Afghanistan         AFG  2014        31627506.0
# 12917  Afghanistan         AFG  2013        30682500.0
# 12672  Afghanistan         AFG  2012        29726803.0
# 12427  Afghanistan         AFG  2011        28809167.0
# 12182  Afghanistan         AFG  2010        27962207.0
# ...            ...         ...   ...               ...
# 1209      Zimbabwe         ZWE  1964         4279561.0
# 967       Zimbabwe         ZWE  1963         4140804.0
# 725       Zimbabwe         ZWE  1962         4006262.0
# 483       Zimbabwe         ZWE  1961         3876638.0
# 241       Zimbabwe         ZWE  1960         3752390.0
#
#        Urban population (% of total)
# 13162                         26.282
# 12917                         25.871
# 12672                         25.468
# 12427                         25.074
# 12182                         24.689
# ...                              ...
# ...

# %% [markdown]
# ### 2. Filter DataFrame Rows
#
# In this exercise you will create conditions and use them to filter the rows of a DataFrame.
# #### Instructions (2 points)
#
# - Retrieve all the rows belong to Year 2000.

# %%
wb_df[wb_df['Year'] == 2000]
# Out:
#                                   CountryName CountryCode  Year  \
# 9699                               Arab World         ARB  2000
# 9700                   Caribbean small states         CSS  2000
# 9701           Central Europe and the Baltics         CEB  2000
# 9702  East Asia & Pacific (all income levels)         EAS  2000
# 9703    East Asia & Pacific (developing only)         EAP  2000
# ...                                       ...         ...   ...
# 9939                    Virgin Islands (U.S.)         VIR  2000
# 9940                       West Bank and Gaza         WBG  2000
# 9941                              Yemen, Rep.         YEM  2000
# 9942                                   Zambia         ZMB  2000
# 9943                                 Zimbabwe         ZWE  2000
#
#       Total Population  Urban population (% of total)
# 9699      2.813558e+08                      53.079995
# 9700      6.454716e+06                      41.494099
# ...

# %% [markdown]
# #### Instructions (2 points)
#
# - Find out which countries and regions have a total population greater than or equal to 100 million in year 1980.

# %%
wb_df[(wb_df["Total Population"] >= 100000000) & (wb_df['Year'] == 1980)]
# Out:
#                                          CountryName CountryCode  Year  \
# 4840                                      Arab World         ARB  1980
# 4842                  Central Europe and the Baltics         CEB  1980
# 4843         East Asia & Pacific (all income levels)         EAS  1980
# 4844           East Asia & Pacific (developing only)         EAP  1980
# 4845                                       Euro area         EMU  1980
# 4846       Europe & Central Asia (all income levels)         ECS  1980
# 4847         Europe & Central Asia (developing only)         ECA  1980
# 4848                                  European Union         EUU  1980
# 4849        Fragile and conflict affected situations         FCS  1980
# 4850          Heavily indebted poor countries (HIPC)         HPC  1980
# 4851                                     High income         HIC  1980
# 4852                            High income: nonOECD         NOC  1980
# ...

# %% [markdown]
# ## Exercise 5.3
# ### 1. Selecting Columns with Square Brackets
#
# The simplest, but not the most powerful way, is to use square brackets.
#
# In the sample code, the same cars data is imported from a CSV files as a Pandas DataFrame. To select only the `cars_per_cap` column from `cars`, you can use:
#
# ```python
# cars['cars_per_cap']
# cars[['cars_per_cap']]
# ```
# The single bracket version gives a Pandas Series, the double bracket version gives a Pandas DataFrame.
#
# ####  Instructions (3 points)
#
# - Use single square brackets to print out the `country` column of `cars` as a Pandas Series.
# - Use double square brackets to print out the `country` column of `cars` as a Pandas DataFrame.
# - Use double square brackets to print out a DataFrame with both the `country` and `drives_right` columns of `cars`, in this order.

# %%
# Import cars data
import pandas as pd
cars = pd.read_csv('https://github.com/huangpen77/BUDT704/raw/main/Chapter06/cars.csv', index_col = 0)
print(cars, '\n')
cars.info()
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JAP           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, US to EG
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cars_per_cap  7 non-null      int64
#  1   country       7 non-null      object
#  2   drives_right  7 non-null      bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 175.0+ bytes

# %%
# Print out country column as Pandas Series
print(cars['country'], '\n')

# Print out country column as Pandas DataFrame
print(cars[['country']], '\n')

# Print out DataFrame with country and drives_right columns
print(cars[['country', 'drives_right']])
# Out:
# US     United States
# AUS        Australia
# JAP            Japan
# IN             India
# RU            Russia
# MOR          Morocco
# EG             Egypt
# Name: country, dtype: object
#
#            country
# US   United States
# AUS      Australia
# JAP          Japan
# IN           India
# RU          Russia
# MOR        Morocco
# EG           Egypt
#
#            country  drives_right
# US   United States          True
# AUS      Australia         False
# JAP          Japan         False
# IN           India         False
# RU          Russia          True
# MOR        Morocco          True
# EG           Egypt          True

# %% [markdown]
# ### 2. Selecting Rows with Square Brackets
# Square brackets can do more than just selecting columns. You can also use them to get rows, or observations, from a DataFrame. The following call selects the first five rows from the `cars` DataFrame:
#
# ```python
# cars[0:5]
# ```
# The result is another DataFrame containing only the rows you specified.
#
# Pay attention: You can only select rows using square brackets if you specify a *slice*, like `0:4`.
# ####  Instructions (4 points)
#
# - Select the the slice of rows from `cars`, starting with `US` and ending with `IN`, and print them out.
# - Select the fourth, fifth and sixth observation, corresponding to row indexes 3, 4 and 5, and print them out.

# %%
# Print out first 4 observations
print(cars[:4], '\n')

# Print out fourth, fifth and sixth observation
print(cars[3:6])
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JAP           588          Japan         False
# IN             18          India         False
#
#      cars_per_cap  country  drives_right
# IN             18    India         False
# RU            200   Russia          True
# MOR            70  Morocco          True
