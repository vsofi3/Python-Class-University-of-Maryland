# %% [markdown]
# ## Exercise 8.1
# ### 1. Single axes plots
#
# It is time now to put together some of what you have learned and combine line plots on a common axes. The data set here comes from records of undergraduate degrees awarded to women in a variety of fields from 1970 to 2011. You can compare trends in degrees most easily by viewing two curves on the same axes.
#
# Here, three pandas Series have been pre-loaded for you: `year` (enumerating years from 1970 to 2011 inclusive), `physical_sciences` (representing the percentage of Physical Sciences degrees awarded to women each in corresponding year), and `computer_science` (representing the percentage of Computer Science degrees awarded to women in each corresponding year).
#
# You will issue two `plt.plot()` commands to draw line plots of different colors on the same set of axes. Here, `year` represents the x-axis, while `physical_sciences` and `computer_science` are the y-axes.

# %%
# Import matplotlib.pyplot
import matplotlib.pyplot as plt
import pandas as pd

# import the file
df = pd.read_csv("https://github.com/huangpen77/BUDT704/raw/main/Chapter09/percent-bachelors-degrees-women-usa.csv")

# read the series
year = df.loc[:,"Year"]
physical_sciences = df.loc[:, "Physical Sciences"]
computer_science = df.loc[:, "Computer Science"]
display(year.head(), physical_sciences.head(), computer_science.head())
# Out:
# 0    1970
# 1    1971
# 2    1972
# 3    1973
# 4    1974
# Name: Year, dtype: int64
# 0    13.8
# 1    14.9
# 2    14.8
# 3    16.5
# 4    18.2
# Name: Physical Sciences, dtype: float64
# 0    13.6
# 1    13.6
# 2    14.9
# 3    16.4
# 4    18.9
# Name: Computer Science, dtype: float64

# %% [markdown]
# #### Instructions (2 points)
#
# - Add a `'blue'` line plot of the % of degrees awarded to women in the Physical Sciences (`physical_sciences`) from 1970 to 2011 (`year`). Note that the x-axis should be specified first.
# - Add a `'red'` line plot of the % of degrees awarded to women in Computer Science (`computer_science`) from 1970 to 2011 (`year`).
# - Use `plt.show()` to display the figure with the curves on the same axes.

# %%
# Plot in blue the % of degrees awarded to women in the Physical Sciences
plt.plot(year, physical_sciences, color='blue')

# Plot in red the % of degrees awarded to women in Computer Science
plt.plot(year, computer_science, color='red')
# Display the figure
plt.show()

# %% [markdown]
# ### 2. Using legend, labels and title
#
# Legends are useful for distinguishing between multiple datasets displayed on common axes. The relevant data are created using specific line colors or markers in various plot commands. Using the keyword argument `label` in the plotting function associates a string to use in a legend.
#
# For example, here, you will plot enrollment of women in the Physical Sciences and in Computer Science over time. You can label each curve by passing a `label` argument to the plotting call, and request a legend using `plt.legend()`. Specifying the keyword argument `loc` determines where the legend will be placed.
#
# #### Instructions (2 points)
# - Modify the plot command provided that draws the enrollment of women in Computer Science over time so that the curve is labelled `'Computer Science'` in the legend.
# - Modify the plot command provided that draws the enrollment of women in the Physical Sciences over time so that the curve is labelled `'Physical Sciences'` in the legend.
# - Add a legend at the lower center (i.e., `loc='lower center'`).
# - label the `x` axis as `'Year'`. Use `plt.xlabel()` method.
# - label the `y` axis as `'Enrollment (%)'`. Use `plt.ylabel()` method.
# - create a title `'Undergraduate enrollment of women'`. Use `plt.title()` method.

# %%
# Specify the label 'Computer Science'
plt.plot(year, computer_science, color='blue', label='Computer Science') 

# Specify the label 'Physical Sciences' 
plt.plot(year, physical_sciences, color='red', label='Physical Sciences')

# Add a legend at the lower center
plt.legend(loc='lower center')

# Add axis labels
plt.xlabel('Year')
plt.ylabel('Enrollment (%)')
# Add title
plt.title('Undergraduate enrollment of women')
# Display the figure
plt.show()

# %% [markdown]
# ### 3. Change line style and marker
# We will further improve upon the plot by changing the default line style and marker.
#
# #### Instructions (2 points)
# - for the `Computer Science` curve, use `dashdot` as the `linestyle`, and `x` as `marker`
# - for the `Physical Science` curve, use `dotted` as the `linestyle`, and `+` as `marker`

# %%
# Specify the linestyle and marker for 'Computer Science'
plt.plot(year, computer_science, color='blue', label='Computer Science', linestyle='dashdot', marker= 'x') 

# Specify the linestyle and marker for  'Physical Sciences' 
plt.plot(year, physical_sciences, color='red', label='Physical Sciences', linestyle='dotted', marker= '+')

# Add a legend at the lower center
plt.legend(loc='lower center')

# Add axis labels
plt.xlabel('Year')
plt.ylabel('Enrollment (%)')
# Add title
plt.title('Undergraduate enrollment of women')
# Display the figure
plt.show()

# %% [markdown]
# ## Exercise 8.2
# ### 1. Using subplot()
#
# In this exercise, you will continue working with the same arrays from the previous exercises: `year`, `physical_sciences`, and `computer_science`. You will use `plt.subplot(m, n, k)` to make the subplot grid of dimensions `m` by `n` and to make the `k`th subplot active (subplots are numbered starting from 1 row-wise from the top left corner of the subplot grid).

# %%
# Import matplotlib.pyplot
import matplotlib.pyplot as plt
import pandas as pd

# import the file
df = pd.read_csv("https://github.com/huangpen77/BUDT704/raw/main/Chapter09/percent-bachelors-degrees-women-usa.csv")

# read the series as it is done in DataCamp kernel
year = df.loc[:,"Year"]
physical_sciences = df.loc[:, "Physical Sciences"]
computer_science = df.loc[:, "Computer Science"]

# %% [markdown]
# #### Instructions (4 points)
#
# - Use `plt.subplot()` to create a figure with 1x2 subplot layout & make the first subplot active.
# - Plot the percentage of degrees awarded to women in Physical Sciences in blue in the active subplot.
# - Use `plt.subplot()` again to make the second subplot active in the current 1x2 subplot grid.
# - Plot the percentage of degrees awarded to women in Computer Science in red in the active subplot.

# %%
# Create a figure with 1x2 subplot and make the left subplot active
plt.subplot(1,2,1)
# Plot in blue the % of degrees awarded to women in the Physical Sciences
plt.plot(year, physical_sciences, color='blue')
plt.title('Physical Sciences')

# Make the right subplot active in the current 1x2 subplot grid
plt.subplot(1,2,1)
# Plot in red the % of degrees awarded to women in Computer Science
plt.plot(year, computer_science, color='red')
plt.title('Computer Science')

# Use plt.tight_layout() to improve the spacing between subplots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2. Using subplots()
#
# Now you have some familiarity with `plt.subplot()`, let's try the alternative syntax where we use `fig` and `ax`.
#
# Here, you will make a **2×2**
# grid of subplots and plot the percentage of degrees awarded to women in Physical Sciences (using `physical_sciences`), in Computer Science (using `computer_science`), in Health Professions (using `health`), and in Education (using `education`).
#
# #### Instructions (4 points)
#
# - Create a figure with **2×2**
# subplot layout, using `fig, ax = plt.subplots()`.
# - in the top, left subplot, plot the % of degrees awarded to women in `Physical Sciences` in `blue`.
# - in the top, right subplot, plot the % of degrees awarded to women in `Computer Science` in `red`.
# - in the bottom, left subplot, plot the % of degrees awarded to women in `Health Professions` in `green`.
# - in the bottom, right subplot, plot the % of degrees awarded to women in `Education` in `yellow`.
#
# When making your plots, be sure to use the variable names specified in the exercise text above (`physical_sciences`, `computer_science`, `health`, and `education`)!

# %%
# create necessary arrays
health = df.loc[:, "Health Professions"]
education = df.loc[:, "Education"]

# Create a figure with 2x2 subplot layout 
fig, ax = plt.subplots(2,2)

# Plot in blue the % of degrees awarded to women in the Physical Sciences in the top, left subplot
ax[1,0].plot(year, physical_sciences, color='blue')
ax[1,0].set_title('Physical Sciences')


# Plot in red the % of degrees awarded to women in Computer Science in the top, right subplot
ax[1,1].plot(year, computer_science, color='red')
ax[1,1].set_title('Computer Science')

# Plot in green the % of degrees awarded to women in Health Professions in the bottom, left subplot
ax[0,0].plot(year, health, color='green')
ax[0,0].set_title('Health Professions')

# Plot in yellow the % of degrees awarded to women in Education in the bottom, right subplot
ax[0,1].plot(year, education, color='yellow')
ax[0,1].set_title('Education')

# Improve the spacing between subplots and display them
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Exercise 8.3
# ### 1. Plot a time series
#
# For this exercise, you will construct a plot showing the stock price history of Apple Inc. The price history consists of data from 2000-01-03 to 2013-12-31.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# import the dataset
stocks = pd.read_csv("https://github.com/huangpen77/BUDT704/raw/main/Chapter09/stocks.csv")

# first column is DateTime. Let's make it index
stocks2 = stocks.set_index("Date")

# the type is still not DateTime Index. 
stocks2.index = pd.to_datetime(stocks2.index)

# read the time series arrays
aapl = stocks2[["AAPL"]]

aapl.index
# Out:
# DatetimeIndex(['2000-01-03', '2000-01-04', '2000-01-05', '2000-01-06',
#                '2000-01-07', '2000-01-10', '2000-01-11', '2000-01-12',
#                '2000-01-13', '2000-01-14',
#                ...
#                '2013-12-17', '2013-12-18', '2013-12-19', '2013-12-20',
#                '2013-12-23', '2013-12-24', '2013-12-26', '2013-12-27',
#                '2013-12-30', '2013-12-31'],
#               dtype='datetime64[ns]', name='Date', length=3521, freq=None)

# %% [markdown]
# #### Instructions (3 points)
#
# - Plot the `aapl` time series. Note the column name is `'AAPL'`. Use `blue` as the line color.
# - Add `'Time'` as `xlabel` and `'Apple Stock Price'` as `ylabel`.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(8, 6)
# Plot the aapl time series in blue
ax.plot(aapl['AAPL'], color='blue')
# set lables
ax.set_xlabel('Time')
ax.set_ylabel('Apple Stock Price')
# Display the plot
plt.show()

# %% [markdown]
# ### 2. Zoom in on a period
# Suppose we are interested in how Apple's stock faired during the 2008 financial crisis and its recovery. We want to plot a slice `'2008-01-01':'2010-12-31'` of the stock price.
#
# #### Instructions (3 points)
#
# - Extract a slice `'2008-01-01':'2010-12-31'` of Apple's stock price and plot it in blue
# - Add `'Time'` as `xlabel` and `'Apple Stock Price'` as `ylabel`.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(8, 6)
# Plot a slice of the aapl time series in blue
ax.plot(aapl.loc['2008-01-01':'2010-12-31', 'AAPL'], color='blue')
# set lables
ax.set_xlabel('Time')
ax.set_ylabel('Apple Stock Price')
# Display the plot
plt.show()
